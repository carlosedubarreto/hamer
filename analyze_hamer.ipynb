# %%
import pickle

file_batch = r"D:\AI\hamer\hamer\demo_out\batch_test1.pkl"
with open(file_batch, 'rb') as f:
    hbatch = pickle.load(f)

# %%
file_result = r"D:\AI\hamer\hamer\demo_out\result_test1.pkl"
with open(file_result, 'rb') as f:
    hres = pickle.load(f)

# %%
hbatch.keys()
# Out:
# dict_keys(['img', 'personid', 'box_center', 'box_size', 'img_size', 'right'])

# %%
hbatch['personid']
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
hbatch['right']
# Out:
# array([0., 1., 0., 1.], dtype=float32)

# %% [markdown]
# # checando dados do resultado

# %%
hres.keys()
# Out:
# dict_keys(['pred_cam', 'global_orient', 'hand_pose', 'betas', 'pred_cam_t', 'focal_length', 'pred_keypoints_3d', 'pred_vertices', 'pred_keypoints_2d'])

# %%
hres['global_orient'].shape
# Out:
# (4, 1, 3, 3)

# %%
hres['hand_pose'].shape
# Out:
# (4, 15, 3, 3)

# %%
hres['hand_pose'][0]
# Out:
# array([[[ 0.537477  , -0.6739677 , -0.5068392 ],
#         [ 0.6290164 ,  0.7207312 , -0.29135022],
#         [ 0.56165546, -0.16221613,  0.8113132 ]],
#
#        [[ 0.97977126, -0.1917925 ,  0.05713199],
#         [ 0.2000101 ,  0.9289702 , -0.3114648 ],
#         [ 0.00666269,  0.31659117,  0.9485388 ]],
#
#        [[ 0.89433473, -0.31027487,  0.3223274 ],
#         [ 0.22340602,  0.9339067 ,  0.27912015],
#         [-0.3876277 , -0.17761698,  0.90454245]],
#
#        [[ 0.52201843, -0.8057062 , -0.2798826 ],
#         [ 0.81624156,  0.5671108 , -0.11015902],
#         [ 0.24748027, -0.17094679,  0.95369315]],
#
#        [[ 0.9860877 ,  0.07859828, -0.14646937],
#         [-0.04934491,  0.97984034,  0.19359252],
#         [ 0.15873262, -0.1836717 ,  0.97008693]],
#
#        [[ 0.9207296 , -0.36941314,  0.12566228],
#         [ 0.37329504,  0.92767805, -0.0080161 ],
#         [-0.1136129 ,  0.05428977,  0.9920407 ]],
#
#        [[ 0.86167383, -0.3723288 ,  0.34480345],
# ...
